# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\mahen\appdata\roaming\python\python311\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\mahen\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
import cv2
from matplotlib import pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
image = cv2.imread("C:/Users/mahen/Intranet/Modele_IA/images/profil_picture/selena_profile_picture.jpg")

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
images = "C:/Users/mahen/Intranet/Modele_IA/images/picture/selena_picture_1.jpg"

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return image, gray_image

# %%
def detect_faces(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    faces = face_cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=minNeighbors, minSize=minSize)
    return faces

# %%
def draw_faces(image, faces):
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)
    return image

# %%
def display_image(image):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# %%
def process_image(image_path):
    image, gray_image = load_image(image_path)
    faces = detect_faces(gray_image)
    if len(faces) == 0:
        print("Aucun visage détecté.")
        return
    image_with_faces = draw_faces(image, faces)
    display_image(image_with_faces)

# %%
process_image(images)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 process_image(images)
#
# Cell In[17], line 2, in process_image(image_path)
#       1 def process_image(image_path):
# ----> 2     image, gray_image = load_image(image_path)
#       3     faces = detect_faces(gray_image)
#       4     if len(faces) == 0:
#
# Cell In[13], line 2, in load_image(image_path)
#       1 def load_image(image_path):
# ----> 2     image = cv2.imread(image_path)
#       3     gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       4     return image, gray_image
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
